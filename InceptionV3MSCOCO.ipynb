# %% [markdown]
# # Image captioning

# %%
import tensorflow as tf

import matplotlib.pyplot as plt

import collections
import random
import numpy as np
import os
import time
import json
from PIL import Image

# %%
# Download caption annotation files
annotation_folder = '/annotations/'
if not os.path.exists(os.path.abspath('.') + annotation_folder):
    annotation_zip = tf.keras.utils.get_file('captions.zip',
                                           cache_subdir=os.path.abspath('.'),
                                           origin='http://images.cocodataset.org/annotations/annotations_trainval2014.zip',
                                           extract=True)
    annotation_file = os.path.dirname(annotation_zip)+'/annotations/captions_train2014.json'
    os.remove(annotation_zip)

# Download image files
image_folder = '/train2014/'
if not os.path.exists(os.path.abspath('.') + image_folder):
    image_zip = tf.keras.utils.get_file('train2014.zip',
                                      cache_subdir=os.path.abspath('.'),
                                      origin='http://images.cocodataset.org/zips/train2014.zip',
                                      extract=True)
    PATH = os.path.dirname(image_zip) + image_folder
    os.remove(image_zip)
else:
    PATH = os.path.abspath('.') + image_folder
# Out:
# Downloading data from http://images.cocodataset.org/annotations/annotations_trainval2014.zip
# 252878848/252872794 [==============================] - 8s 0us/step
# Downloading data from http://images.cocodataset.org/zips/train2014.zip
# 13510574080/13510573713 [==============================] - 378s 0us/step

# %%
with open(annotation_file, 'r') as f:
    annotations = json.load(f)

# %%
# Group all captions together having the same image ID.
image_path_to_caption = collections.defaultdict(list)
for val in annotations['annotations']:
    caption = f"<start> {val['caption']} <end>"
    image_path = PATH + 'COCO_train2014_' + '%012d.jpg' % (val['image_id'])
    image_path_to_caption[image_path].append(caption)

# %%
image_paths = list(image_path_to_caption.keys())
random.shuffle(image_paths)

# Select the first 6000 image_paths from the shuffled set.
# Approximately each image id has 5 captions associated with it, so that will
# lead to 30,000 examples.
train_image_paths = image_paths[:30000]
print(len(train_image_paths))
# Out:
# 30000

# %%
train_captions = []
img_name_vector = []

for image_path in train_image_paths:
  caption_list = image_path_to_caption[image_path]
  train_captions.extend(caption_list)
  img_name_vector.extend([image_path] * len(caption_list))

# %%
print(train_captions[0])
Image.open(img_name_vector[0])
# Out:
# <start> A car and truck parked in front of a store. <end>
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=640x480 at 0x7FC3295E6FD0>

# %%
def load_image(image_path):
    img = tf.io.read_file(image_path)
    img = tf.image.decode_jpeg(img, channels=3)
    img = tf.image.resize(img, (299, 299))
    img = tf.keras.applications.inception_v3.preprocess_input(img)
    return img, image_path

# %%
image_model = tf.keras.applications.InceptionV3(include_top=False,
                                                weights='imagenet')
new_input = image_model.input
hidden_layer = image_model.layers[-1].output

image_features_extract_model = tf.keras.Model(new_input, hidden_layer)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/inception_v3/inception_v3_weights_tf_dim_ordering_tf_kernels_notop.h5
# 87916544/87910968 [==============================] - 1s 0us/step

# %%
# !pip install tqdm
from tqdm import tqdm
# Out:
# Requirement already satisfied: tqdm in /usr/local/lib/python3.7/dist-packages (4.41.1)

# %%
# Get unique images
encode_train = sorted(set(img_name_vector))

# Feel free to change batch_size according to your system configuration
image_dataset = tf.data.Dataset.from_tensor_slices(encode_train)
image_dataset = image_dataset.map(
  load_image, num_parallel_calls=tf.data.AUTOTUNE).batch(16)

for img, path in tqdm(image_dataset):
  batch_features = image_features_extract_model(img)
  batch_features = tf.reshape(batch_features,
                              (batch_features.shape[0], -1, batch_features.shape[3]))

  for bf, p in zip(batch_features, path):
    path_of_feature = p.numpy().decode("utf-8")
    np.save(path_of_feature, bf.numpy())
# Out:
# 100%|██████████| 1875/1875 [04:19<00:00,  7.22it/s]

# %%
# Find the maximum length of any caption in the dataset
def calc_max_length(tensor):
    return max(len(t) for t in tensor)

# %%
# Choose the top 5000 words from the vocabulary
top_k = 20000
tokenizer = tf.keras.preprocessing.text.Tokenizer(num_words=top_k,
                                                  oov_token="<unk>",
                                                  filters='!"#$%&()*+.,-/:;=?@[\]^_`{|}~')
tokenizer.fit_on_texts(train_captions)

# %%
tokenizer.word_index['<pad>'] = 0
tokenizer.index_word[0] = '<pad>'

# %%
# Create the tokenized vectors
train_seqs = tokenizer.texts_to_sequences(train_captions)

# %%
# Pad each vector to the max_length of the captions
# If you do not provide a max_length value, pad_sequences calculates it automatically
cap_vector = tf.keras.preprocessing.sequence.pad_sequences(train_seqs, padding='post')

# %%
# Calculates the max_length, which is used to store the attention weights
max_length = calc_max_length(train_seqs)

# %% [markdown]
# ## Split the data into training and testing

# %%
img_to_cap_vector = collections.defaultdict(list)
for img, cap in zip(img_name_vector, cap_vector):
  img_to_cap_vector[img].append(cap)

# Create training and validation sets using an 80-20 split randomly.
img_keys = list(img_to_cap_vector.keys())
random.shuffle(img_keys)

slice_index = int(len(img_keys)*0.8)
img_name_train_keys, img_name_val_keys = img_keys[:slice_index], img_keys[slice_index:]

img_name_train = []
cap_train = []
for imgt in img_name_train_keys:
  capt_len = len(img_to_cap_vector[imgt])
  img_name_train.extend([imgt] * capt_len)
  cap_train.extend(img_to_cap_vector[imgt])

img_name_val = []
cap_val = []
for imgv in img_name_val_keys:
  capv_len = len(img_to_cap_vector[imgv])
  img_name_val.extend([imgv] * capv_len)
  cap_val.extend(img_to_cap_vector[imgv])

# %%
len(img_name_train), len(cap_train), len(img_name_val), len(cap_val)
# Out:
# (32360, 32360, 8095, 8095)

# %%
# Feel free to change these parameters according to your system's configuration

BATCH_SIZE = 64
BUFFER_SIZE = 1000
embedding_dim = 256
units = 512
vocab_size = top_k + 1
num_steps = len(img_name_train) // BATCH_SIZE
# Shape of the vector extracted from InceptionV3 is (64, 2048)
# These two variables represent that vector shape
features_shape = 2048
attention_features_shape = 64

# %%
# Load the numpy files
def map_func(img_name, cap):
  img_tensor = np.load(img_name.decode('utf-8')+'.npy')
  return img_tensor, cap

# %%
dataset = tf.data.Dataset.from_tensor_slices((img_name_train, cap_train))

# Use map to load the numpy files in parallel
dataset = dataset.map(lambda item1, item2: tf.numpy_function(
          map_func, [item1, item2], [tf.float32, tf.int32]),
          num_parallel_calls=tf.data.AUTOTUNE)

# Shuffle and batch
dataset = dataset.shuffle(BUFFER_SIZE).batch(BATCH_SIZE)
dataset = dataset.prefetch(buffer_size=tf.data.AUTOTUNE)

# %%
class BahdanauAttention(tf.keras.Model):
  def __init__(self, units):
    super(BahdanauAttention, self).__init__()
    self.W1 = tf.keras.layers.Dense(units)
    self.W2 = tf.keras.layers.Dense(units)
    self.V = tf.keras.layers.Dense(1)

  def call(self, features, hidden):
    # features(CNN_encoder output) shape == (batch_size, 64, embedding_dim)

    # hidden shape == (batch_size, hidden_size)
    # hidden_with_time_axis shape == (batch_size, 1, hidden_size)
    hidden_with_time_axis = tf.expand_dims(hidden, 1)

    # attention_hidden_layer shape == (batch_size, 64, units)
    attention_hidden_layer = (tf.nn.tanh(self.W1(features) +
                                         self.W2(hidden_with_time_axis)))

    # score shape == (batch_size, 64, 1)
    # This gives you an unnormalized score for each image feature.
    score = self.V(attention_hidden_layer)

    # attention_weights shape == (batch_size, 64, 1)
    attention_weights = tf.nn.softmax(score, axis=1)

    # context_vector shape after sum == (batch_size, hidden_size)
    context_vector = attention_weights * features
    context_vector = tf.reduce_sum(context_vector, axis=1)

    return context_vector, attention_weights

# %%
class CNN_Encoder(tf.keras.Model):
    # Since you have already extracted the features and dumped it
    # This encoder passes those features through a Fully connected layer
    def __init__(self, embedding_dim):
        super(CNN_Encoder, self).__init__()
        # shape after fc == (batch_size, 64, embedding_dim)
        self.fc = tf.keras.layers.Dense(embedding_dim)

    def call(self, x):
        x = self.fc(x)
        x = tf.nn.relu(x)
        return x

# %%
class RNN_Decoder(tf.keras.Model):
  def __init__(self, embedding_dim, units, vocab_size):
    super(RNN_Decoder, self).__init__()
    self.units = units

    self.embedding = tf.keras.layers.Embedding(vocab_size, embedding_dim)
    self.gru = tf.keras.layers.GRU(self.units,
                                   return_sequences=True,
                                   return_state=True,
                                   recurrent_initializer='glorot_uniform')
    self.fc1 = tf.keras.layers.Dense(self.units)
    self.fc2 = tf.keras.layers.Dense(vocab_size)

    self.attention = BahdanauAttention(self.units)

  def call(self, x, features, hidden):
    # defining attention as a separate model
    context_vector, attention_weights = self.attention(features, hidden)

    # x shape after passing through embedding == (batch_size, 1, embedding_dim)
    x = self.embedding(x)

    # x shape after concatenation == (batch_size, 1, embedding_dim + hidden_size)
    x = tf.concat([tf.expand_dims(context_vector, 1), x], axis=-1)

    # passing the concatenated vector to the GRU
    output, state = self.gru(x)

    # shape == (batch_size, max_length, hidden_size)
    x = self.fc1(output)

    # x shape == (batch_size * max_length, hidden_size)
    x = tf.reshape(x, (-1, x.shape[2]))

    # output shape == (batch_size * max_length, vocab)
    x = self.fc2(x)

    return x, state, attention_weights

  def reset_state(self, batch_size):
    return tf.zeros((batch_size, self.units))

# %%
encoder = CNN_Encoder(embedding_dim)
decoder = RNN_Decoder(embedding_dim, units, vocab_size)

# %%
optimizer = tf.keras.optimizers.Adam()
loss_object = tf.keras.losses.SparseCategoricalCrossentropy(
    from_logits=True, reduction='none')


def loss_function(real, pred):
  mask = tf.math.logical_not(tf.math.equal(real, 0))
  loss_ = loss_object(real, pred)

  mask = tf.cast(mask, dtype=loss_.dtype)
  loss_ *= mask

  return tf.reduce_mean(loss_)

# %% [markdown]
# ## Checkpoint

# %%
checkpoint_path = "./checkpoints/train"
ckpt = tf.train.Checkpoint(encoder=encoder,
                           decoder=decoder,
                           optimizer=optimizer)
ckpt_manager = tf.train.CheckpointManager(ckpt, checkpoint_path, max_to_keep=5)

# %%
start_epoch = 0
if ckpt_manager.latest_checkpoint:
  start_epoch = int(ckpt_manager.latest_checkpoint.split('-')[-1])
  # restoring the latest checkpoint in checkpoint_path
  ckpt.restore(ckpt_manager.latest_checkpoint)

# %% [markdown]
# ## Training

# %%
# adding this in a separate cell because if you run the training cell
# many times, the loss_plot array will be reset
loss_plot = []

# %%
@tf.function
def train_step(img_tensor, target):
  loss = 0

  # initializing the hidden state for each batch
  # because the captions are not related from image to image
  hidden = decoder.reset_state(batch_size=target.shape[0])

  dec_input = tf.expand_dims([tokenizer.word_index['<start>']] * target.shape[0], 1)

  with tf.GradientTape() as tape:
      features = encoder(img_tensor)

      for i in range(1, target.shape[1]):
          # passing the features through the decoder
          predictions, hidden, _ = decoder(dec_input, features, hidden)

          loss += loss_function(target[:, i], predictions)

          # using teacher forcing
          dec_input = tf.expand_dims(target[:, i], 1)

  total_loss = (loss / int(target.shape[1]))

  trainable_variables = encoder.trainable_variables + decoder.trainable_variables

  gradients = tape.gradient(loss, trainable_variables)

  optimizer.apply_gradients(zip(gradients, trainable_variables))

  return loss, total_loss

# %%
EPOCHS = 20
for epoch in range(start_epoch, EPOCHS):
    start = time.time()
    total_loss = 0

    for (batch, (img_tensor, target)) in enumerate(dataset):
        batch_loss, t_loss = train_step(img_tensor, target)
        total_loss += t_loss

        if batch % 100 == 0:
            average_batch_loss = batch_loss.numpy()/int(target.shape[1])
            print(f'Epoch {epoch+1} Batch {batch} Loss {average_batch_loss:.4f}')
    # storing the epoch end loss value to plot later
    loss_plot.append(total_loss / num_steps)

    if epoch % 5 == 0:
      ckpt_manager.save()

    print(f'Epoch {epoch+1} Loss {total_loss/num_steps:.6f}')
    print(f'Time taken for 1 epoch {time.time()-start:.2f} sec\n')
# Out:
# Epoch 1 Batch 0 Loss 2.1715
# Epoch 1 Batch 100 Loss 1.1669
# Epoch 1 Batch 200 Loss 1.1472
# Epoch 1 Batch 300 Loss 1.0262
# Epoch 1 Batch 400 Loss 0.8766
# Epoch 1 Batch 500 Loss 0.9201
# Epoch 1 Batch 600 Loss 0.8808
# Epoch 1 Batch 700 Loss 0.8531
# Epoch 1 Batch 800 Loss 0.7716
# Epoch 1 Batch 900 Loss 0.8316
# Epoch 1 Batch 1000 Loss 0.7639
# Epoch 1 Batch 1100 Loss 0.7334
# Epoch 1 Batch 1200 Loss 0.7791
# Epoch 1 Batch 1300 Loss 0.7155
# Epoch 1 Batch 1400 Loss 0.7331
# Epoch 1 Batch 1500 Loss 0.7874
# Epoch 1 Batch 1600 Loss 0.8555
# Epoch 1 Batch 1700 Loss 0.7165
# Epoch 1 Batch 1800 Loss 0.6960
# Epoch 1 Loss 0.844389
# Time taken for 1 epoch 536.40 sec
#
# Epoch 2 Batch 0 Loss 0.6957
# Epoch 2 Batch 100 Loss 0.6972
# Epoch 2 Batch 200 Loss 0.7082
# Epoch 2 Batch 300 Loss 0.6710
# Epoch 2 Batch 400 Loss 0.6868
# Epoch 2 Batch 500 Loss 0.7917
# Epoch 2 Batch 600 Loss 0.6966
# Epoch 2 Batch 700 Loss 0.7177
# Epoch 2 Batch 800 Loss 0.7881
# Epoch 2 Batch 900 Loss 0.6956
# Epoch 2 Batch 1000 Loss 0.6473
# Epoch 2 Batch 1100 Loss 0.6699
# Epoch 2 Batch 1200 Loss 0.7024
# Epoch 2 Batch 1300 Loss 0.6138
# Epoch 2 Batch 1400 Loss 0.6972
# Epoch 2 Batch 1500 Loss 0.6760
# Epoch 2 Batch 1600 Loss 0.7001
# Epoch 2 Batch 1700 Loss 0.6544
# Epoch 2 Batch 1800 Loss 0.7007
# Epoch 2 Loss 0.679352
# Time taken for 1 epoch 454.09 sec
#
# Epoch 3 Batch 0 Loss 0.7171
# Epoch 3 Batch 100 Loss 0.6420
# Epoch 3 Batch 200 Loss 0.6072
# Epoch 3 Batch 300 Loss 0.6293
# Epoch 3 Batch 400 Loss 0.6848
# Epoch 3 Batch 500 Loss 0.6494
# Epoch 3 Batch 600 Loss 0.7625
# Epoch 3 Batch 700 Loss 0.6797
# Epoch 3 Batch 800 Loss 0.6074
# Epoch 3 Batch 900 Loss 0.6026
# Epoch 3 Batch 1000 Loss 0.6600
# Epoch 3 Batch 1100 Loss 0.6379
# Epoch 3 Batch 1200 Loss 0.6394
# Epoch 3 Batch 1300 Loss 0.6309
# Epoch 3 Batch 1400 Loss 0.6157
# Epoch 3 Batch 1500 Loss 0.6166
# Epoch 3 Batch 1600 Loss 0.6150
# Epoch 3 Batch 1700 Loss 0.6055
# Epoch 3 Batch 1800 Loss 0.6599
# Epoch 3 Loss 0.629602
# Time taken for 1 epoch 453.08 sec
#
# Epoch 4 Batch 0 Loss 0.5970
# Epoch 4 Batch 100 Loss 0.6166
# Epoch 4 Batch 200 Loss 0.5405
# Epoch 4 Batch 300 Loss 0.5913
# Epoch 4 Batch 400 Loss 0.6311
# Epoch 4 Batch 500 Loss 0.5564
# Epoch 4 Batch 600 Loss 0.5352
# Epoch 4 Batch 700 Loss 0.6329
# Epoch 4 Batch 800 Loss 0.5948
# Epoch 4 Batch 900 Loss 0.5249
# Epoch 4 Batch 1000 Loss 0.5540
# Epoch 4 Batch 1100 Loss 0.5480
# Epoch 4 Batch 1200 Loss 0.5557
# Epoch 4 Batch 1300 Loss 0.5932
# Epoch 4 Batch 1400 Loss 0.5625
# Epoch 4 Batch 1500 Loss 0.6505
# Epoch 4 Batch 1600 Loss 0.5665
# Epoch 4 Batch 1700 Loss 0.5428
# Epoch 4 Batch 1800 Loss 0.5730
# Epoch 4 Loss 0.594964
# Time taken for 1 epoch 452.37 sec
#
# Epoch 5 Batch 0 Loss 0.5854
# Epoch 5 Batch 100 Loss 0.5573
# Epoch 5 Batch 200 Loss 0.5595
# Epoch 5 Batch 300 Loss 0.5512
# Epoch 5 Batch 400 Loss 0.6624
# Epoch 5 Batch 500 Loss 0.5460
# Epoch 5 Batch 600 Loss 0.5486
# Epoch 5 Batch 700 Loss 0.5372
# Epoch 5 Batch 800 Loss 0.5626
# Epoch 5 Batch 900 Loss 0.6257
# Epoch 5 Batch 1000 Loss 0.5604
# Epoch 5 Batch 1100 Loss 0.5645
# Epoch 5 Batch 1200 Loss 0.5441
# Epoch 5 Batch 1300 Loss 0.5291
# Epoch 5 Batch 1400 Loss 0.5115
# Epoch 5 Batch 1500 Loss 0.5935
# Epoch 5 Batch 1600 Loss 0.5267
# Epoch 5 Batch 1700 Loss 0.6586
# Epoch 5 Batch 1800 Loss 0.5029
# Epoch 5 Loss 0.566743
# Time taken for 1 epoch 451.89 sec
#
# Epoch 6 Batch 0 Loss 0.5419
# Epoch 6 Batch 100 Loss 0.4997
# Epoch 6 Batch 200 Loss 0.5731
# Epoch 6 Batch 300 Loss 0.5051
# Epoch 6 Batch 400 Loss 0.5668
# Epoch 6 Batch 500 Loss 0.5087
# Epoch 6 Batch 600 Loss 0.5051
# Epoch 6 Batch 700 Loss 0.6033
# Epoch 6 Batch 800 Loss 0.5398
# Epoch 6 Batch 900 Loss 0.5500
# Epoch 6 Batch 1000 Loss 0.4956
# Epoch 6 Batch 1100 Loss 0.5224
# Epoch 6 Batch 1200 Loss 0.5405
# Epoch 6 Batch 1300 Loss 0.5266
# Epoch 6 Batch 1400 Loss 0.5141
# Epoch 6 Batch 1500 Loss 0.4966
# Epoch 6 Batch 1600 Loss 0.5381
# Epoch 6 Batch 1700 Loss 0.5812
# Epoch 6 Batch 1800 Loss 0.5588
# Epoch 6 Loss 0.542892
# Time taken for 1 epoch 453.02 sec
#
# Epoch 7 Batch 0 Loss 0.5361
# Epoch 7 Batch 100 Loss 0.5382
# Epoch 7 Batch 200 Loss 0.5178
# Epoch 7 Batch 300 Loss 0.4858
# Epoch 7 Batch 400 Loss 0.5331
# Epoch 7 Batch 500 Loss 0.5633
# Epoch 7 Batch 600 Loss 0.4906
# Epoch 7 Batch 700 Loss 0.5581
# Epoch 7 Batch 800 Loss 0.5046
# Epoch 7 Batch 900 Loss 0.5024
# Epoch 7 Batch 1000 Loss 0.5369
# Epoch 7 Batch 1100 Loss 0.5538
# Epoch 7 Batch 1200 Loss 0.5086
# Epoch 7 Batch 1300 Loss 0.5575
# Epoch 7 Batch 1400 Loss 0.5242
# Epoch 7 Batch 1500 Loss 0.5591
# Epoch 7 Batch 1600 Loss 0.4914
# Epoch 7 Batch 1700 Loss 0.5108
# Epoch 7 Batch 1800 Loss 0.4851
# Epoch 7 Loss 0.521989
# Time taken for 1 epoch 453.81 sec
#
# Epoch 8 Batch 0 Loss 0.5330
# Epoch 8 Batch 100 Loss 0.5321
# Epoch 8 Batch 200 Loss 0.5034
# Epoch 8 Batch 300 Loss 0.4994
# Epoch 8 Batch 400 Loss 0.4902
# Epoch 8 Batch 500 Loss 0.4769
# Epoch 8 Batch 600 Loss 0.5198
# Epoch 8 Batch 700 Loss 0.5190
# Epoch 8 Batch 800 Loss 0.4790
# Epoch 8 Batch 900 Loss 0.5115
# Epoch 8 Batch 1000 Loss 0.5227
# Epoch 8 Batch 1100 Loss 0.5124
# Epoch 8 Batch 1200 Loss 0.4719
# Epoch 8 Batch 1300 Loss 0.5491
# Epoch 8 Batch 1400 Loss 0.5244
# Epoch 8 Batch 1500 Loss 0.4993
# Epoch 8 Batch 1600 Loss 0.4576
# Epoch 8 Batch 1700 Loss 0.5234
# Epoch 8 Batch 1800 Loss 0.4605
# Epoch 8 Loss 0.504141
# Time taken for 1 epoch 457.06 sec
#
# Epoch 9 Batch 0 Loss 0.5323
# Epoch 9 Batch 100 Loss 0.4598
# Epoch 9 Batch 200 Loss 0.4432
# Epoch 9 Batch 300 Loss 0.5162
# Epoch 9 Batch 400 Loss 0.4638
# Epoch 9 Batch 500 Loss 0.4726
# Epoch 9 Batch 600 Loss 0.4654
# Epoch 9 Batch 700 Loss 0.5132
# Epoch 9 Batch 800 Loss 0.4927
# Epoch 9 Batch 900 Loss 0.4834
# Epoch 9 Batch 1000 Loss 0.4837
# Epoch 9 Batch 1100 Loss 0.5047
# Epoch 9 Batch 1200 Loss 0.4798
# Epoch 9 Batch 1300 Loss 0.4952
# Epoch 9 Batch 1400 Loss 0.4728
# Epoch 9 Batch 1500 Loss 0.4865
# Epoch 9 Batch 1600 Loss 0.4865
# Epoch 9 Batch 1700 Loss 0.5159
# Epoch 9 Batch 1800 Loss 0.4768
# Epoch 9 Loss 0.487219
# Time taken for 1 epoch 456.44 sec
#
# Epoch 10 Batch 0 Loss 0.5117
# Epoch 10 Batch 100 Loss 0.4986
# Epoch 10 Batch 200 Loss 0.5023
# Epoch 10 Batch 300 Loss 0.4570
# Epoch 10 Batch 400 Loss 0.4874
# Epoch 10 Batch 500 Loss 0.4660
# Epoch 10 Batch 600 Loss 0.4461
# Epoch 10 Batch 700 Loss 0.5145
# Epoch 10 Batch 800 Loss 0.4655
# Epoch 10 Batch 900 Loss 0.5613
# Epoch 10 Batch 1000 Loss 0.4539
# Epoch 10 Batch 1100 Loss 0.4830
# Epoch 10 Batch 1200 Loss 0.4643
# Epoch 10 Batch 1300 Loss 0.4749
# Epoch 10 Batch 1400 Loss 0.4374
# Epoch 10 Batch 1500 Loss 0.4232
# Epoch 10 Batch 1600 Loss 0.5070
# Epoch 10 Batch 1700 Loss 0.4095
# Epoch 10 Batch 1800 Loss 0.5232
# Epoch 10 Loss 0.472490
# Time taken for 1 epoch 454.32 sec
#
# Epoch 11 Batch 0 Loss 0.4650
# Epoch 11 Batch 100 Loss 0.4565
# Epoch 11 Batch 200 Loss 0.4505
# Epoch 11 Batch 300 Loss 0.4447
# Epoch 11 Batch 400 Loss 0.4558
# Epoch 11 Batch 500 Loss 0.4493
# Epoch 11 Batch 600 Loss 0.4396
# Epoch 11 Batch 700 Loss 0.4455
# Epoch 11 Batch 800 Loss 0.4044
# Epoch 11 Batch 900 Loss 0.4811
# Epoch 11 Batch 1000 Loss 0.4170
# Epoch 11 Batch 1100 Loss 0.5220
# Epoch 11 Batch 1200 Loss 0.4555
# Epoch 11 Batch 1300 Loss 0.5260
# Epoch 11 Batch 1400 Loss 0.4371
# Epoch 11 Batch 1500 Loss 0.4924
# Epoch 11 Batch 1600 Loss 0.4412
# Epoch 11 Batch 1700 Loss 0.4466
# Epoch 11 Batch 1800 Loss 0.5103
# Epoch 11 Loss 0.458709
# Time taken for 1 epoch 455.99 sec
#
# Epoch 12 Batch 0 Loss 0.4752
# Epoch 12 Batch 100 Loss 0.4436
# Epoch 12 Batch 200 Loss 0.4449
# Epoch 12 Batch 300 Loss 0.4051
# Epoch 12 Batch 400 Loss 0.4471
# Epoch 12 Batch 500 Loss 0.4282
# Epoch 12 Batch 600 Loss 0.4139
# Epoch 12 Batch 700 Loss 0.4451
# Epoch 12 Batch 800 Loss 0.4925
# Epoch 12 Batch 900 Loss 0.4826
# Epoch 12 Batch 1000 Loss 0.4680
# Epoch 12 Batch 1100 Loss 0.4404
# Epoch 12 Batch 1200 Loss 0.4650
# Epoch 12 Batch 1300 Loss 0.4144
# Epoch 12 Batch 1400 Loss 0.4294
# Epoch 12 Batch 1500 Loss 0.4761
# Epoch 12 Batch 1600 Loss 0.4395
# Epoch 12 Batch 1700 Loss 0.4209
# Epoch 12 Batch 1800 Loss 0.4375
# Epoch 12 Loss 0.446566
# Time taken for 1 epoch 454.93 sec
#
# Epoch 13 Batch 0 Loss 0.5252
# Epoch 13 Batch 100 Loss 0.4929
# Epoch 13 Batch 200 Loss 0.4348
# Epoch 13 Batch 300 Loss 0.4140
# Epoch 13 Batch 400 Loss 0.4471
# Epoch 13 Batch 500 Loss 0.4247
# Epoch 13 Batch 600 Loss 0.4621
# Epoch 13 Batch 700 Loss 0.4847
# Epoch 13 Batch 800 Loss 0.4039
# Epoch 13 Batch 900 Loss 0.4209
# Epoch 13 Batch 1000 Loss 0.4269
# Epoch 13 Batch 1100 Loss 0.3995
# Epoch 13 Batch 1200 Loss 0.4609
# Epoch 13 Batch 1300 Loss 0.4660
# Epoch 13 Batch 1400 Loss 0.4521
# Epoch 13 Batch 1500 Loss 0.4260
# Epoch 13 Batch 1600 Loss 0.4644
# Epoch 13 Batch 1700 Loss 0.3824
# Epoch 13 Batch 1800 Loss 0.4296
# Epoch 13 Loss 0.436418
# Time taken for 1 epoch 455.53 sec
#
# Epoch 14 Batch 0 Loss 0.4468
# Epoch 14 Batch 100 Loss 0.4442
# Epoch 14 Batch 200 Loss 0.4233
# Epoch 14 Batch 300 Loss 0.4290
# Epoch 14 Batch 400 Loss 0.4442
# Epoch 14 Batch 500 Loss 0.4152
# Epoch 14 Batch 600 Loss 0.4116
# Epoch 14 Batch 700 Loss 0.4399
# Epoch 14 Batch 800 Loss 0.4003
# Epoch 14 Batch 900 Loss 0.4341
# Epoch 14 Batch 1000 Loss 0.4228
# Epoch 14 Batch 1100 Loss 0.4069
# Epoch 14 Batch 1200 Loss 0.4573
# Epoch 14 Batch 1300 Loss 0.4098
# Epoch 14 Batch 1400 Loss 0.3970
# Epoch 14 Batch 1500 Loss 0.3860
# Epoch 14 Batch 1600 Loss 0.3754
# Epoch 14 Batch 1700 Loss 0.4489
# Epoch 14 Batch 1800 Loss 0.4419
# Epoch 14 Loss 0.425808
# Time taken for 1 epoch 455.87 sec
#
# Epoch 15 Batch 0 Loss 0.4487
# Epoch 15 Batch 100 Loss 0.4209
# Epoch 15 Batch 200 Loss 0.4482
# Epoch 15 Batch 300 Loss 0.4110
# Epoch 15 Batch 400 Loss 0.4353
# Epoch 15 Batch 500 Loss 0.4395
# Epoch 15 Batch 600 Loss 0.4075
# Epoch 15 Batch 700 Loss 0.4804
# Epoch 15 Batch 800 Loss 0.4005
# Epoch 15 Batch 900 Loss 0.3815
# Epoch 15 Batch 1000 Loss 0.4207
# Epoch 15 Batch 1100 Loss 0.4465
# Epoch 15 Batch 1200 Loss 0.4257
# Epoch 15 Batch 1300 Loss 0.4345
# Epoch 15 Batch 1400 Loss 0.3903
# Epoch 15 Batch 1500 Loss 0.3828
# Epoch 15 Batch 1600 Loss 0.4311
# Epoch 15 Batch 1700 Loss 0.3677
# Epoch 15 Batch 1800 Loss 0.4122
# Epoch 15 Loss 0.415490
# Time taken for 1 epoch 457.08 sec
#
# Epoch 16 Batch 0 Loss 0.4279
# Epoch 16 Batch 100 Loss 0.4384
# Epoch 16 Batch 200 Loss 0.3932
# Epoch 16 Batch 300 Loss 0.3885
# Epoch 16 Batch 400 Loss 0.3851
# Epoch 16 Batch 500 Loss 0.3852
# Epoch 16 Batch 600 Loss 0.4361
# Epoch 16 Batch 700 Loss 0.4455
# Epoch 16 Batch 800 Loss 0.4387
# Epoch 16 Batch 900 Loss 0.4467
# Epoch 16 Batch 1000 Loss 0.4168
# Epoch 16 Batch 1100 Loss 0.4309
# Epoch 16 Batch 1200 Loss 0.4094
# Epoch 16 Batch 1300 Loss 0.4324
# Epoch 16 Batch 1400 Loss 0.4033
# Epoch 16 Batch 1500 Loss 0.4125
# Epoch 16 Batch 1600 Loss 0.3964
# Epoch 16 Batch 1700 Loss 0.4013
# Epoch 16 Batch 1800 Loss 0.3746
# Epoch 16 Loss 0.407060
# Time taken for 1 epoch 457.34 sec
#
# Epoch 17 Batch 0 Loss 0.4273
# Epoch 17 Batch 100 Loss 0.3974
# Epoch 17 Batch 200 Loss 0.4011
# Epoch 17 Batch 300 Loss 0.3934
# Epoch 17 Batch 400 Loss 0.3876
# Epoch 17 Batch 500 Loss 0.3797
# Epoch 17 Batch 600 Loss 0.3723
# Epoch 17 Batch 700 Loss 0.4004
# Epoch 17 Batch 800 Loss 0.3705
# Epoch 17 Batch 900 Loss 0.4144
# Epoch 17 Batch 1000 Loss 0.3645
# Epoch 17 Batch 1100 Loss 0.3407
# Epoch 17 Batch 1200 Loss 0.4383
# Epoch 17 Batch 1300 Loss 0.4347
# Epoch 17 Batch 1400 Loss 0.3875
# Epoch 17 Batch 1500 Loss 0.3838
# Epoch 17 Batch 1600 Loss 0.3790
# Epoch 17 Batch 1700 Loss 0.3784
# Epoch 17 Batch 1800 Loss 0.3886
# Epoch 17 Loss 0.398816
# Time taken for 1 epoch 456.71 sec
#
# Epoch 18 Batch 0 Loss 0.4138
# Epoch 18 Batch 100 Loss 0.3817
# Epoch 18 Batch 200 Loss 0.3947
# Epoch 18 Batch 300 Loss 0.4350
# Epoch 18 Batch 400 Loss 0.3739
# Epoch 18 Batch 500 Loss 0.3749
# Epoch 18 Batch 600 Loss 0.4091
# Epoch 18 Batch 700 Loss 0.4120
# Epoch 18 Batch 800 Loss 0.4023
# Epoch 18 Batch 900 Loss 0.3629
# Epoch 18 Batch 1000 Loss 0.4148
# Epoch 18 Batch 1100 Loss 0.4031
# Epoch 18 Batch 1200 Loss 0.3914
# Epoch 18 Batch 1300 Loss 0.4342
# Epoch 18 Batch 1400 Loss 0.3683
# Epoch 18 Batch 1500 Loss 0.4160
# Epoch 18 Batch 1600 Loss 0.3940
# Epoch 18 Batch 1700 Loss 0.4193
# Epoch 18 Batch 1800 Loss 0.4098
# Epoch 18 Loss 0.391041
# Time taken for 1 epoch 456.49 sec
#
# Epoch 19 Batch 0 Loss 0.3930
# Epoch 19 Batch 100 Loss 0.4105
# Epoch 19 Batch 200 Loss 0.3549
# Epoch 19 Batch 300 Loss 0.3926
# Epoch 19 Batch 400 Loss 0.3735
# Epoch 19 Batch 500 Loss 0.3921
# Epoch 19 Batch 600 Loss 0.3600
# Epoch 19 Batch 700 Loss 0.3877
# Epoch 19 Batch 800 Loss 0.3863
# Epoch 19 Batch 900 Loss 0.4105
# Epoch 19 Batch 1000 Loss 0.4123
# Epoch 19 Batch 1100 Loss 0.3791
# Epoch 19 Batch 1200 Loss 0.3641
# Epoch 19 Batch 1300 Loss 0.4044
# Epoch 19 Batch 1400 Loss 0.3819
# Epoch 19 Batch 1500 Loss 0.3847
# Epoch 19 Batch 1600 Loss 0.3706
# Epoch 19 Batch 1700 Loss 0.3725
# Epoch 19 Batch 1800 Loss 0.3427
# Epoch 19 Loss 0.384119
# Time taken for 1 epoch 457.21 sec
#
# Epoch 20 Batch 0 Loss 0.3946
# Epoch 20 Batch 100 Loss 0.3591
# Epoch 20 Batch 200 Loss 0.4148
# Epoch 20 Batch 300 Loss 0.3345
# Epoch 20 Batch 400 Loss 0.3701
# Epoch 20 Batch 500 Loss 0.3858
# Epoch 20 Batch 600 Loss 0.3951
# Epoch 20 Batch 700 Loss 0.4224
# Epoch 20 Batch 800 Loss 0.4101
# Epoch 20 Batch 900 Loss 0.4020
# Epoch 20 Batch 1000 Loss 0.3733
# Epoch 20 Batch 1100 Loss 0.3936
# Epoch 20 Batch 1200 Loss 0.3477
# Epoch 20 Batch 1300 Loss 0.3747
# Epoch 20 Batch 1400 Loss 0.3395
# Epoch 20 Batch 1500 Loss 0.3923
# Epoch 20 Batch 1600 Loss 0.3663
# Epoch 20 Batch 1700 Loss 0.3526
# Epoch 20 Batch 1800 Loss 0.3500
# Epoch 20 Loss 0.380771
# Time taken for 1 epoch 456.27 sec

# %%
plt.plot(loss_plot)
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.title('Loss Plot')
plt.show()

# %% [markdown]
# ## Caption!

# %%
def evaluate(image):
    attention_plot = np.zeros((max_length, attention_features_shape))

    hidden = decoder.reset_state(batch_size=1)

    temp_input = tf.expand_dims(load_image(image)[0], 0)
    img_tensor_val = image_features_extract_model(temp_input)
    img_tensor_val = tf.reshape(img_tensor_val, (img_tensor_val.shape[0],
                                                 -1,
                                                 img_tensor_val.shape[3]))

    features = encoder(img_tensor_val)

    dec_input = tf.expand_dims([tokenizer.word_index['<start>']], 0)
    result = []

    for i in range(max_length):
        predictions, hidden, attention_weights = decoder(dec_input,
                                                         features,
                                                         hidden)

        #attention_plot[i] = tf.reshape(attention_weights, (-1, )).numpy()

        predicted_id = tf.random.categorical(predictions, 1)[0][0].numpy()
        result.append(tokenizer.index_word[predicted_id])

        if tokenizer.index_word[predicted_id] == '<end>':
            return result, attention_plot

        dec_input = tf.expand_dims([predicted_id], 0)

    attention_plot = attention_plot[:len(result), :]
    return result, attention_plot

# %%
def plot_attention(image, result, attention_plot):
    temp_image = np.array(Image.open(image))

    fig = plt.figure(figsize=(10, 10))

    len_result = len(result)
    for i in range(len_result):
        temp_att = np.resize(attention_plot[i], (8, 8))
        grid_size = max(np.ceil(len_result/2), 2)
        ax = fig.add_subplot(grid_size, grid_size, i+1)
        ax.set_title(result[i])
        img = ax.imshow(temp_image)
        ax.imshow(temp_att, cmap='gray', alpha=0.6, extent=img.get_extent())

    plt.tight_layout()
    plt.show()

# %%
# captions on the validation set
rid = np.random.randint(0, len(img_name_val))
image = img_name_val[rid]
real_caption = ' '.join([tokenizer.index_word[i]
                        for i in cap_val[rid] if i not in [0]])
result, attention_plot = evaluate(image)

print('Real Caption:', real_caption)
print('Prediction Caption:', ' '.join(result))
plot_attention(image, result, attention_plot)
# Out:
# Real Caption: <start> a person lifts left ski up while skiing on a mountain <end>
# Prediction Caption: a man skiing on a snow covered slope <end>

# %%
image_url = 'https://tensorflow.org/images/surf.jpg'
image_extension = image_url[-4:]
image_path = tf.keras.utils.get_file('image'+image_extension, origin=image_url)
#image = "./twochild.jpg"

result, attention_plot = evaluate(image_path)
print('Prediction Caption:', ' '.join(result))
#plot_attention(image_path, result, attention_plot)
# opening the image
Image.open(image_path)
# Out:
# Downloading data from https://tensorflow.org/images/surf.jpg
# 65536/64400 [==============================] - 0s 3us/step
# Prediction Caption: a man riding on his surf board in the ocean waves of a wave <end>
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=640x426 at 0x7FC031909210>

# %%
image = "./test.jpg"

result, attention_plot = evaluate(image)
print('Prediction Caption:', ' '.join(result))
#plot_attention(image_path, result, attention_plot)
# opening the image
Image.open(image)
# Out:
# Prediction Caption: a baseball player swinging a baseball bat <end>
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=1232x821 at 0x7FC03199B850>
